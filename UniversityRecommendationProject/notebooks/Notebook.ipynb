# %%
import sys
sys.path.insert(0,'../')

# %%
from main import df

# %%
df
# Out:
#             Math Grade  Physics Grade  ...  Suggestion Based on Top 4 grades                        Suggestion Based on Mean
# Student ID                             ...
# 0                   89             62  ...                         Education                                 Economic Policy
# 1                   47             66  ...                           Anatomy  Sustainable Chemistry and Economic Development
# 2                   64             65  ...              Chemistry Journalism                Chemical Supply Chain Management
# 3                   95             55  ...           Computational Chemistry                          Statistical Demography
# 4                   72             98  ...                     Lab Assistant                            Journalism and Media
# ...                ...            ...  ...                               ...                                             ...
# ...
